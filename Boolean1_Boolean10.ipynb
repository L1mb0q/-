# %% [markdown]
# <a href="https://colab.research.google.com/github/L1mb0q/-/blob/main/Boolean1_Boolean10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Boolean1
A = int(input("Введите A: "))
print(A>0)
# Out:
# Введите A: 9
# True

# %%
#Boolean2
A = int(input("Введите A: "))
print(A % 2 != 0)
# Out:
# Введите A: 2
# False

# %%
#Boolean3
A = int(input("Введите A: "))
print(A % 2 == 0)
# Out:
# Введите A: 3
# False

# %%
#Boolean4
A = int(input("Введите A: "))
B = int(input("Введите B: "))
print(A>2)
print(B <= 3)
# Out:
# Введите A: 1
# Введите B: 5
# False
# False

# %%
#Boolean5
A = int(input("Введите A: "))
B = int(input("Введите B: "))
print(A >= 0 or B < -2)
# Out:
# Введите A: -1
# Введите B: -5
# True

# %%
#Boolean6
A = int(input("Введите A: "))
B = int(input("Введите B: "))
C = int(input("Введите C: "))
print(A < B < C)
# Out:
# Введите A: 3
# Введите B: 2
# Введите C: 1
# False

# %%
#Boolean7
A = int(input("Введите A: "))
B = int(input("Введите B: "))
C = int(input("Введите C: "))
print((A < B < C) or (C < B < A))
# Out:
# Введите A: 1
# Введите B: 3
# Введите C: 1
# False

# %%
#Boolean8
A = int(input("Введите A: "))
B = int(input("Введите B: "))
print(A % 2 != 0)
print(B % 2 != 0)
# Out:
# Введите A: 2
# Введите B: 7
# False
# True

# %%
#Boolean9
A = int(input("Введите A: "))
B = int(input("Введите B: "))
if A % 2 != 0 or B % 2 != 0:
  print (True)
else:
  print(False)
# Out:
# Введите A: 2
# Введите B: 2
# False

# %%
#Boolean10
A = int(input("Введите A: "))
B = int(input("Введите B: "))
print((A % 2 != 0) != (B % 2 != 0))
# Out:
# Введите A: 3
# Введите B: 3
# False
