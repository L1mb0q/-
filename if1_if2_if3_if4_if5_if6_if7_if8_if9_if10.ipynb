# %% [markdown]
# <a href="https://colab.research.google.com/github/L1mb0q/-/blob/main/if1_if2_if3_if4_if5_if6_if7_if8_if9_if10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if1
a = int(input("Введите целое число: "))
if a > 0:
  print(a + 1)
else:
  print(a)
# Out:
# Введите целое число: -1
# -1

# %%
#if2
a = int(input("Введите целое число: "))
if a > 0:
  print(a + 1)
else:
  print(a - 2)
# Out:
# Введите целое число: -1
# -3

# %%
#if3
a = int(input("Введите целое число: "))
b = 10
if a > 0:
  print(a + 1)
if a < 0:
  print(a - 2)
if a == 0:
  print(b)
# Out:
# Введите целое число: 0
# 10

# %%
#if4
a = int(input("Введите целое число: "))
b = int(input("Введите целое число: "))
c = int(input("Введите целое число: "))
count = 0
if a > 0:
    count += 1
if b > 0:
    count += 1
if c > 0:
    count += 1
    print(count)
# Out:
# Введите целое число: 5
# Введите целое число: 2
# Введите целое число: 3
# 3

# %%
#if5
a = int(input("Введите целое число: "))
b = int(input("Введите целое число: "))
c = int(input("Введите целое число: "))
count = 0
count1 = 0
if a > 0:
    count += 1
elif a < 0:
    count1 += 1
if b > 0:
    count += 1
elif b < 0:
    count1 += 1
if c > 0:
    count += 1
elif c < 0:
    count1 += 1
print(f"Положительных: {count}")
print(f"Отрицательных: {count1}")
# Out:
# Введите целое число: 5
# Введите целое число: -3
# Введите целое число: -2
# Положительных: 1
# Отрицательных: 2

# %%
#if6
a = int(input("Введите число: "))
b = int(input("Введите число: "))
if a > b:
  print(a)
if b > a:
  print(b)
# Out:
# Введите число: 6
# Введите число: 9
# 9

# %%
#if7
a = int(input("Введите число: "))
b = int(input("Введите число: "))
if a < b:
    print(1)
else:
    print(2)
# Out:
# Введите число: 5
# Введите число: 3
# 2

# %%
#if8
a = int(input("Введите число: "))
b = int(input("Введите число: "))
if a > b:
  print(a, b)
if b > a:
  print(b, a)
# Out:
# Введите число: 3
# Введите число: 9
# 9 3

# %%
#if9
a = float(input("Введите a: "))
b = float(input("Введите b: "))

if a > b:
    temp = a
    a = b
    b = temp

print("a =", a)
print("b =", b)
# Out:
# Введите A: 5
# Введите B: 7
# a = 5.0
# b = 7.0

# %%
#if10
a = int(input("Введите a: "))
b = int(input("Введите b: "))

if a != b:
    s = a + b
    a = s
    b = s
else:
    a = 0
    b = 0

print("a =", a)
print("b =", b)
# Out:
# Введите a: 5
# Введите b: 6
# a = 11
# b = 11
